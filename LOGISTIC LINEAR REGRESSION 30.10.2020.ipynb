# %%
#import packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
raw_data=pd.read_csv('German_Credit_data.csv')
raw_data.head()
# Out:
#    Creditability  Status_of_existing_account  Duration_of_Credit_month  \
# 0              1                           1                        18
# 1              1                           1                         9
# 2              1                           2                        12
# 3              1                           1                        12
# 4              1                           1                        12
#
#    Payment_Status_of_Previous_Credit(Credit_history)  Purpose_of_loan  \
# 0                                                  4                2
# 1                                                  4                0
# 2                                                  2                9
# 3                                                  4                0
# 4                                                  4                0
#
#    Credit_Amount  Value_of_Savings_account&bonds  Years_of_Present_Employment  \
# ...

# %% [markdown]
# #  3.data preperation

# %%
raw_data.shape
# Out:
# (1000, 21)

# %%
raw_data.describe()
# Out:
#        Creditability  Status_of_existing_account  Duration_of_Credit_month  \
# count    1000.000000                 1000.000000               1000.000000
# mean        0.700000                    2.577000                 20.903000
# std         0.458487                    1.257638                 12.058814
# min         0.000000                    1.000000                  4.000000
# 25%         0.000000                    1.000000                 12.000000
# 50%         1.000000                    2.000000                 18.000000
# 75%         1.000000                    4.000000                 24.000000
# max         1.000000                    4.000000                 72.000000
#
#        Payment_Status_of_Previous_Credit(Credit_history)  Purpose_of_loan  \
# count                                         1000.00000      1000.000000
# mean                                             2.54500         2.828000
# ...

# %%
#checking datatype and missing values
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Creditability                                      1000 non-null   int64
#  1   Status_of_existing_account                         1000 non-null   int64
#  2   Duration_of_Credit_month                           1000 non-null   int64
#  3   Payment_Status_of_Previous_Credit(Credit_history)  1000 non-null   int64
#  4   Purpose_of_loan                                    1000 non-null   int64
#  5   Credit_Amount                                      1000 non-null   int64
#  6   Value_of_Savings_account&bonds                     1000 non-null   int64
#  7   Years_of_Present_Employment                        1000 non-null   int64
#  8   Percentage_of_disposable_income                    1000 non-null   int64
# ...

# %% [markdown]
# # 4.Exploratory Data Analysis

# %%
raw_data.hist(figsize=(20,15))
plt.show()

# %%
#to undetstand the number of levels in each variables
raw_data.nunique()
# Out:
# Creditability                                          2
# Status_of_existing_account                             4
# Duration_of_Credit_month                              33
# Payment_Status_of_Previous_Credit(Credit_history)      5
# Purpose_of_loan                                       10
# Credit_Amount                                        923
# Value_of_Savings_account&bonds                         5
# Years_of_Present_Employment                            5
# Percentage_of_disposable_income                        4
# Sex_&_Marital_Status                                   4
# Guarantors/Debtors                                     3
# Duration_in_Present_Residence                          4
# Property                                               4
# Age_in_years                                          53
# Concurrent_Credits                                     3
# Housing                                                3
# ...

# %%
#plotting age distribution
df_good=raw_data[raw_data['Creditability']==1]
df_bad=raw_data[raw_data['Creditability']==0]

fig, ax= plt.subplots(nrows=2, figsize=(12,8))
print(fig,ax)
plt.subplots_adjust(hspace= 0.4, top= 0.8)

g1=sns.distplot(df_good['Age_in_years'], ax=ax[0], color='g')
g1=sns.distplot(df_bad['Age_in_years'], ax=ax[0], color='r')

g1.set_title('Age distribution', fontsize=15)
g1.set_xlabel('Age')
g1.set_ylabel('Frequency')

g2=sns.countplot(x='Age_in_years', data=raw_data, palette='hls', ax=ax[1], hue='Creditability')

g2.set_title('Age Counting by Creditability', fontsize=15)
g2.set_xlabel('Age')
g2.set_ylabel('Count')
plt.xticks(rotation=90)
plt.show()
# Out:
# Figure(864x576) [<matplotlib.axes._subplots.AxesSubplot object at 0x00000290DC9F77C8>
# ...

# %% [markdown]
# # 4.1 Class Distribution

# %%
print(raw_data.groupby('Creditability').size())
# Out:
# Creditability
# 0    300
# 1    700
# dtype: int64

# %%
#this gives you the calculation of the target labels.ehich category of the target
total_len = len(raw_data.Creditability)
percentage_labels = (raw_data.Creditability.value_counts()/total_len)*100
percentage_labels
# Out:
# 1    70.0
# 0    30.0
# Name: Creditability, dtype: float64

# %%
'''
aa=pd.DataFrame(percentage_labels)
aa.plot(kind='bar')'''
# Out:
# "\naa=pd.DataFrame(percentage_labels)\naa.plot(kind='bar')"

# %%
#graphical representation of the target label percnetage
sns.set()
sns.countplot(raw_data.Creditability).set_title('Data distribution')
ax = plt.gca()
for p in ax.patches:
    height = p.get_height()
    ax.text(p.get_x() + p.get_width()/2.,height + 2,
            '{:.2f}%'.format(100*(height/total_len)),fontsize=12, ha='center', va='bottom')
sns.set(font_scale=1.5)
ax.set_xlabel("labels for credibility attribute")
ax.set_ylabel('number of records')
plt.show()

# %%
'''ax = plt.gca()
for p in ax.patches:
    print(p)'''
# Out:
# 'ax = plt.gca()\nfor p in ax.patches:\n    print(p)'

# %% [markdown]
# # correlation

# %%
#check correlation
raw_data.corr()
# Out:
#                                                    Creditability  \
# Creditability                                           1.000000
# Status_of_existing_account                              0.350847
# Duration_of_Credit_month                               -0.214927
# Payment_Status_of_Previous_Credit(Credit_history)       0.228785
# Purpose_of_loan                                        -0.017979
# Credit_Amount                                          -0.154740
# Value_of_Savings_account&bonds                          0.178943
# Years_of_Present_Employment                             0.116002
# Percentage_of_disposable_income                        -0.072404
# Sex_&_Marital_Status                                    0.088184
# Guarantors/Debtors                                      0.025137
# Duration_in_Present_Residence                          -0.002967
# Property                                               -0.142612
# ...

# %%
#checking correlation and correlation plot
import matplotlib.pyplot as plt
import seaborn as sns
corr=raw_data.corr()
plt.figure(figsize=(30,30))

sns.heatmap(corr[(corr >=0.5) | (corr <=-0.5)],vmax=.8, linewidths=0.01,
           square=True, annot=True, cmap='GnBu',linecolor="white")
plt.title('correlation between features')
# Out:
# Text(0.5, 1, 'correlation between features')

# %% [markdown]
# # 5.Logistic Regression

# %%
#splitting target variable
predictor = raw_data.iloc[:, raw_data.columns != 'Creditability']
target = raw_data.iloc[:, raw_data.columns == 'Creditability' ]

# %%
#let us now split the data set into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(predictor,target,test_size= 0.30, random_state = 0)
print('x_train', x_train.shape)
print('x_test',x_test.shape)
print('y_train', y_train.shape)
print('y_test',y_test.shape)
# Out:
# x_train (700, 20)
# x_test (300, 20)
# y_train (700, 1)
# y_test (300, 1)

# %% [markdown]
# # 5.2 Building Logistic Regression Base Model

# %%
import statsmodels.api as sm

#build logit model
logit = sm.Logit(y_train,x_train)

#fit the model
model1 = logit.fit()

#printing logistic regression model results
model1.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.480402
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                          Results: Logit
# ...
# Model:                          Logit                      Pseudo R-squared:           0.197
# Dependent Variable:             Creditability              AIC:                        712.5629
# Date:                           2020-11-08 20:54           BIC:                        803.5845
# No. Observations:               700                        Log-Likelihood:             -336.28
# Df Model:                       19                         LL-Null:                    -418.79
# Df Residuals:                   680                        LLR p-value:                2.6772e-25
# Converged:                      1.0000                     Scale:                      1.0000
# No. Iterations:                 6.0000
# ...

# %%
#predit values using test data
y_pred = model1.predict(x_test)
y_pred
# Out:
# 993    0.841483
# 859    0.489402
# 298    0.878734
# 553    0.945764
# 672    0.488180
#          ...
# 167    0.963939
# 998    0.852205
# 984    0.793468
# 491    0.958278
# 10     0.748442
# Length: 300, dtype: float64

# %%
# making y_pred as DataFrame
predicted_df = pd.DataFrame(y_pred)
predicted_df.head(5)
# Out:
#             0
# 993  0.841483
# 859  0.489402
# 298  0.878734
# 553  0.945764
# 672  0.488180

# %%
# assinging the class 0 and 1 based on the threshold value 0.5
predicted_df["Predicted_Class"] = np.where(predicted_df[0]>=0.50,1,0)
predicted_df.head()
# Out:
#             0  Predicted_Class
# 993  0.841483                1
# 859  0.489402                0
# 298  0.878734                1
# 553  0.945764                1
# 672  0.488180                0

# %% [markdown]
# # Model Accuracy

# %%
#checking the accuracy with test data
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predicted_df['Predicted_Class']))
# Out:
# 0.74

# %% [markdown]
# # Evaluate model

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix = confusion_matrix(y_test, predicted_df['Predicted_Class']).ravel()
confusion_matrix
# Out:
# array([ 37,  63,  15, 185], dtype=int64)

# %% [markdown]
# The results from the confusion matrix are telling us that 37 and 185 are the number of correct predictions. 63 and 15 are the number of incorrect predictions

# %% [markdown]
# # Classification report¶

# %% [markdown]
# This is another method to examine the performance of classification mdoel

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,predicted_df['Predicted_Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.37      0.49       100
#            1       0.75      0.93      0.83       200
#
#     accuracy                           0.74       300
#    macro avg       0.73      0.65      0.66       300
# weighted avg       0.73      0.74      0.71       300

# %% [markdown]
# f1 score is harmonic mean of precision and recall

# %% [markdown]
# # ROC curve

# %%
y_pred_prob = model1.predict(x_test)

from sklearn.metrics import roc_curve
#generate ROC curve values: fpr,tpr, thresholds
fpr,tpr,thresholds = roc_curve(y_test, y_pred_prob)

#plot ROC curve
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.xlabel('false positive rate')
plt.ylabel('true positive rate')
plt.title('ROC curve')
plt.show()

# %%
#AUC
from sklearn.metrics import roc_auc_score
roc_auc_score(y_test,predicted_df['Predicted_Class'])
#print('area under the curve is', roc_auc_score(y_test,predicted_df['Predicted_Class']))
# Out:
# 0.6475

# %% [markdown]
# # Cohen's Kappa

# %%
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
models_report = pd.DataFrame(columns=cols)
from sklearn import metrics
tmp1 = pd.Series({'Model': 'Logistic Regressin Base Model',
                 'R_Squared Value': model1.prsquared,
                 'ROC score': metrics.roc_auc_score(y_test,predicted_df['Predicted_Class']),
                 'Precision Score': metrics.precision_score(y_test,predicted_df['Predicted_Class']),
                 'Recall Score': metrics.recall_score(y_test,predicted_df['Predicted_Class']),
                 'Accuracy_Score': metrics.accuracy_score(y_test,predicted_df['Predicted_Class']),
                 'Kappa_Score': metrics.cohen_kappa_score(y_test,predicted_df['Predicted_Class'])})

model1_report = models_report.append(tmp1, ignore_index=True)
model1_report
# Out:
#                            Model  R_Squared Value  ROC score  Precision Score  \
# 0  Logistic Regressin Base Model         0.197014     0.6475         0.745968
#
#    Recall Score  Accuracy_Score  Kappa_Score
# 0         0.925            0.74     0.335227

# %% [markdown]
# # 5.3 Removing 'Credit Amount' variable and building a Logit model¶

# %% [markdown]
# # lets try to build a After removing 'Credit_amount' since its correlated with 'Duration_of_Credit_month'

# %%
# Removing "credit amount" column and using filter function  we creating new train
x_train1=x_train.filter(['Status_of_existing_account','Duration_of_Credit_month',
                         'Payment_Status_of_Previous_Credit(Credit_history)','Purpose_of_loan','Value_of_Savings_account&bonds',
                        'Years_of_Present_Employment','Percentage_of_disposable_income','Sex_&_Marital_Status','Guarantors/Debtors',
                         'Duration_in_Present_Residence', 'Property', 'Age_in_years',
       'Concurrent_Credits', 'Housing', 'No_of_Credits_at_this__Bank',
       'Occupation', 'No_of_dependents', 'Telephone', 'Foreign_Worker'])
x_test1=x_test.filter(['Status_of_existing_account','Duration_of_Credit_month',
                         'Payment_Status_of_Previous_Credit(Credit_history)','Purpose_of_loan','Value_of_Savings_account&bonds',
                        'Years_of_Present_Employment','Percentage_of_disposable_income','Sex_&_Marital_Status','Guarantors/Debtors',
                         'Duration_in_Present_Residence', 'Property', 'Age_in_years',
       'Concurrent_Credits', 'Housing', 'No_of_Credits_at_this__Bank',
       'Occupation', 'No_of_dependents', 'Telephone', 'Foreign_Worker'])
x_train1.shape,x_test1.shape
# Out:
# ((700, 19), (300, 19))

# %%
# Build logit model
logit2=sm.Logit(y_train,x_train1)

#fit the model
model2=logit2.fit()

#printing logistic regression models results
model2.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.481612
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                          Results: Logit
# ...
# Model:                          Logit                      Pseudo R-squared:           0.195
# Dependent Variable:             Creditability              AIC:                        712.2562
# Date:                           2020-11-08 20:53           BIC:                        798.7267
# No. Observations:               700                        Log-Likelihood:             -337.13
# Df Model:                       18                         LL-Null:                    -418.79
# Df Residuals:                   681                        LLR p-value:                1.8620e-25
# Converged:                      1.0000                     Scale:                      1.0000
# No. Iterations:                 6.0000
# ...

# %%
# predict values using test data
y_pred2=model2.predict(x_test1)

# %%
# making y_pred as Dataframe
predicted_df2=pd.DataFrame(y_pred2)
predicted_df2.head(5)
# Out:
#             0
# 993  0.827863
# 859  0.480910
# 298  0.866885
# 553  0.943799
# 672  0.496007

# %%
#assigning the class 0 and 1 based on threshold value 0.5
predicted_df2['Predicted_Class']=np.where(predicted_df2[0]>=0.50,1,0)
predicted_df2.tail(5)
# Out:
#             0  Predicted_Class
# 167  0.962955                1
# 998  0.864725                1
# 984  0.764521                1
# 491  0.960359                1
# 10   0.765681                1

# %%
# checking the accuracy with test data
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
print(accuracy_score(y_test,predicted_df2['Predicted_Class']))
# Out:
# 0.7433333333333333

# %%
#confusion matrix
confusion_matrix=confusion_matrix(y_test,predicted_df2['Predicted_Class']).ravel()
confusion_matrix
# Out:
# array([ 39,  61,  16, 184], dtype=int64)

# %%
print(classification_report(y_test,predicted_df2['Predicted_Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.39      0.50       100
#            1       0.75      0.92      0.83       200
#
#     accuracy                           0.74       300
#    macro avg       0.73      0.66      0.67       300
# weighted avg       0.74      0.74      0.72       300

# %%
# ROC CURVE- A receiver operating characteristic curve, or ROC curve, is a graphical plot that illustrates the diagnostic 
# ability of a binary classifier system as its discrimination threshold is varied.
y_pred_prob=model2.predict(x_test1)
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
# Out:
# Text(0, 0.5, 'True Positive Rate')

# %%
#AUC
roc_auc_score(y_test,predicted_df2['Predicted_Class'])
# Out:
# 0.655

# %%
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
models_report = pd.DataFrame(columns=cols)
from sklearn import metrics
tmp2 = pd.Series({'Model': 'Logistic Regressin Base Model after removing Credit_amount',
                 'R_Squared Value': model2.prsquared,
                 'ROC score': metrics.roc_auc_score(y_test,predicted_df2['Predicted_Class']),
                 'Precision Score': metrics.precision_score(y_test,predicted_df2['Predicted_Class']),
                 'Recall Score': metrics.recall_score(y_test,predicted_df2['Predicted_Class']),
                 'Accuracy_Score': metrics.accuracy_score(y_test,predicted_df2['Predicted_Class']),
                 'Kappa_Score': metrics.cohen_kappa_score(y_test,predicted_df2['Predicted_Class'])})

model2_report = models_report.append(tmp2, ignore_index=True)
model2_report
# Out:
#                                                Model  R_Squared Value  \
# 0  Logistic Regressin Base Model after removing C...         0.194992
#
#    ROC score  Precision Score  Recall Score  Accuracy_Score  Kappa_Score
# 0      0.655          0.75102          0.92        0.743333     0.349296

# %% [markdown]
# # 5.3 Removing 'Duration of credit month' variable and building a Logit model¶
#
# # let try to build after removing duration of credit month to see the difference in two model

# %%
x_train2=x_train.filter(['Status_of_existing_account',
                         'Payment_Status_of_Previous_Credit(Credit_history)','Purpose_of_loan','Value_of_Savings_account&bonds',
                        'Years_of_Present_Employment','Percentage_of_disposable_income','Sex_&_Marital_Status','Guarantors/Debtors',
                         'Duration_in_Present_Residence', 'Property', 'Age_in_years',
       'Concurrent_Credits', 'Housing', 'No_of_Credits_at_this__Bank',
       'Occupation', 'No_of_dependents', 'Telephone', 'Foreign_Worker','Credit_Amount'])
x_test2=x_test.filter(['Status_of_existing_account',
                         'Payment_Status_of_Previous_Credit(Credit_history)','Purpose_of_loan','Value_of_Savings_account&bonds',
                        'Years_of_Present_Employment','Percentage_of_disposable_income','Sex_&_Marital_Status','Guarantors/Debtors',
                         'Duration_in_Present_Residence', 'Property', 'Age_in_years',
       'Concurrent_Credits', 'Housing', 'No_of_Credits_at_this__Bank',
       'Occupation', 'No_of_dependents', 'Telephone', 'Foreign_Worker','Credit_Amount'])
x_train2.shape,x_test2.shape
# Out:
# ((700, 19), (300, 19))

# %%
# Build logit model
logit3=sm.Logit(y_train,x_train2)

#fit the model
model3=logit3.fit()

#printing logistic regression models results
model3.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.485443
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                          Results: Logit
# ...
# Model:                          Logit                      Pseudo R-squared:           0.189
# Dependent Variable:             Creditability              AIC:                        717.6196
# Date:                           2020-11-08 20:53           BIC:                        804.0901
# No. Observations:               700                        Log-Likelihood:             -339.81
# Df Model:                       18                         LL-Null:                    -418.79
# Df Residuals:                   681                        LLR p-value:                2.0902e-24
# Converged:                      1.0000                     Scale:                      1.0000
# No. Iterations:                 6.0000
# ...

# %%
# predict values using test data
y_pred3=model3.predict(x_test2)

# %%
# making y_pred as Dataframe
predicted_df3=pd.DataFrame(y_pred3)
predicted_df3.head(5)
# Out:
#             0
# 993  0.868776
# 859  0.433240
# 298  0.885488
# 553  0.930537
# 672  0.478826

# %%
#assigning the class 0 and 1 based on threshold value 0.5
predicted_df3['Predicted_Class']=np.where(predicted_df3[0]>=0.50,1,0)
predicted_df3.head(5)
# Out:
#             0  Predicted_Class
# 993  0.868776                1
# 859  0.433240                0
# 298  0.885488                1
# 553  0.930537                1
# 672  0.478826                0

# %%
# checking the accuracy with test data
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
print(accuracy_score(y_test,predicted_df3['Predicted_Class']))
# Out:
# 0.7466666666666667

# %%
#confusion matrix
confusion_matrix=confusion_matrix(y_test,predicted_df3['Predicted_Class']).ravel()
confusion_matrix
# Out:
# array([ 38,  62,  14, 186], dtype=int64)

# %%
print(classification_report(y_test,predicted_df3['Predicted_Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.38      0.50       100
#            1       0.75      0.93      0.83       200
#
#     accuracy                           0.75       300
#    macro avg       0.74      0.66      0.67       300
# weighted avg       0.74      0.75      0.72       300

# %%
# ROC CURVE- A receiver operating characteristic curve, or ROC curve, is a graphical plot that illustrates the diagnostic 
# ability of a binary classifier system as its discrimination threshold is varied.
y_pred_prob=model3.predict(x_test2)
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC curve")
plt.show()

# %%
#AUC
roc_auc_score(y_test,predicted_df3['Predicted_Class'])
# Out:
# 0.655

# %%
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
models_report = pd.DataFrame(columns=cols)
from sklearn import metrics
tmp3 = pd.Series({'Model': 'Logistic Regressin Base Model after removing  Duration of credit month',
                 'R_Squared Value': model3.prsquared,
                 'ROC score': metrics.roc_auc_score(y_test,predicted_df3['Predicted_Class']),
                 'Precision Score': metrics.precision_score(y_test,predicted_df3['Predicted_Class']),
                 'Recall Score': metrics.recall_score(y_test,predicted_df3['Predicted_Class']),
                 'Accuracy_Score': metrics.accuracy_score(y_test,predicted_df3['Predicted_Class']),
                 'Kappa_Score': metrics.cohen_kappa_score(y_test,predicted_df3['Predicted_Class'])})

model3_report = models_report.append(tmp3, ignore_index=True)
model3_report
# Out:
#                                                Model  R_Squared Value  \
# 0  Logistic Regressin Base Model after removing  ...         0.188589
#
#    ROC score  Precision Score  Recall Score  Accuracy_Score  Kappa_Score
# 0      0.655             0.75          0.93        0.746667     0.352273

# %%
# comparison of logistic regression models after removing credit amount and duration of credit month
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
model_LR = pd.DataFrame(columns=cols)
model_LR=model_LR.append([model1_report,model2_report,model3_report],ignore_index=True)
model_LR
# we can able to see the model performance has improved in terms ROC score,Recall Score,Accuracy_score
# Out:
#                                                Model  R_Squared Value  \
# 0                      Logistic Regressin Base Model         0.197014
# 1  Logistic Regressin Base Model after removing C...         0.194992
# 2  Logistic Regressin Base Model after removing  ...         0.188589
#
#    ROC score  Precision Score  Recall Score  Accuracy_Score  Kappa_Score
# 0     0.6475         0.745968         0.925        0.740000     0.335227
# 1     0.6550         0.751020         0.920        0.743333     0.349296
# 2     0.6550         0.750000         0.930        0.746667     0.352273

# %% [markdown]
# # Treating Multicollinearity and building logit model

# %%
# removing variable has threshold value of VIF above 5
print("\nVariance Inflation Factor")
cnames=x_train2.columns
for i in np.arange(0,len(cnames)):
    xvars=list(cnames)
    yvar=xvars.pop(i)
    mod=sm.OLS(x_train2[yvar],(x_train[xvars]))
    res=mod.fit()
    vif=1/(1-res.rsquared)
    print(yvar,round(vif,3))
# Out:
# Variance Inflation Factor
# Status_of_existing_account 5.517
# Payment_Status_of_Previous_Credit(Credit_history) 9.777
# Purpose_of_loan 2.102
# Value_of_Savings_account&bonds 2.973
# Years_of_Present_Employment 11.115
# Percentage_of_disposable_income 9.411
# Sex_&_Marital_Status 17.217
# Guarantors/Debtors 6.764
# Duration_in_Present_Residence 8.804
# Property 8.375
# Age_in_years 15.04
# Concurrent_Credits 14.37
# Housing 18.895
# No_of_Credits_at_this__Bank 9.646
# Occupation 25.373
# No_of_dependents 11.424
# Telephone 11.765
# Foreign_Worker 23.613
# Credit_Amount 3.059

# %%
# removing variables having more than 10 VIF values
VIF_10=['Years_of_Present_Employment','Sex_&_Marital_Status','Age_in_years','Concurrent_Credits', 'Housing', 
       'Occupation', 'No_of_dependents',  'Foreign_Worker']
to_keep=[x for x in x_train2 if x not in VIF_10]

x_train_vif=x_train2[to_keep]
print(x_train_vif.shape)
to_keep=[x for x in x_test2 if x not in VIF_10]
x_test_vif=x_test2[to_keep]
print(x_test_vif.shape)
# Out:
# (700, 11)
# (300, 11)

# %%
# Build logit model
logit4=sm.Logit(y_train,x_train_vif)

#fit the model
model4=logit4.fit()

#printing logistic regression models results
model4.summary2()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.496600
#          Iterations 6
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                          Results: Logit
# ...
# Model:                          Logit                      Pseudo R-squared:           0.170
# Dependent Variable:             Creditability              AIC:                        717.2397
# Date:                           2020-11-08 20:53           BIC:                        767.3015
# No. Observations:               700                        Log-Likelihood:             -347.62
# Df Model:                       10                         LL-Null:                    -418.79
# Df Residuals:                   689                        LLR p-value:                1.3978e-25
# Converged:                      1.0000                     Scale:                      1.0000
# No. Iterations:                 6.0000
# ...

# %%
# predict values using test data
y_pred4=model4.predict(x_test_vif)

# %%
# making y_pred as Dataframe
predicted_df4=pd.DataFrame(y_pred4)
predicted_df4.head(5)
# Out:
#             0
# 993  0.844670
# 859  0.444881
# 298  0.909533
# 553  0.930615
# 672  0.703086

# %%
#assigning the class 0 and 1 based on threshold value 0.5
predicted_df4['Predicted_Class']=np.where(predicted_df4[0]>=0.50,1,0)
predicted_df4.head(5)
# Out:
#             0  Predicted_Class
# 993  0.844670                1
# 859  0.444881                0
# 298  0.909533                1
# 553  0.930615                1
# 672  0.703086                1

# %%
# checking the accuracy with test data
from sklearn.metrics import accuracy_score,confusion_matrix,roc_curve,roc_auc_score
print(accuracy_score(y_test,predicted_df4['Predicted_Class']))
# Out:
# 0.77

# %%
#confusion matrix
confusion_matrix=confusion_matrix(y_test,predicted_df4['Predicted_Class']).ravel()
confusion_matrix
# Out:
# array([ 42,  58,  11, 189], dtype=int64)

# %%
print(classification_report(y_test,predicted_df4['Predicted_Class']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.42      0.55       100
#            1       0.77      0.94      0.85       200
#
#     accuracy                           0.77       300
#    macro avg       0.78      0.68      0.70       300
# weighted avg       0.77      0.77      0.75       300

# %%
# ROC CURVE- A receiver operating characteristic curve, or ROC curve, is a graphical plot that illustrates the diagnostic 
# ability of a binary classifier system as its discrimination threshold is varied.
y_pred_prob=model4.predict(x_test_vif)
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title("ROC curve")
plt.show()

# %%
#AUC
roc_auc_score(y_test,predicted_df4['Predicted_Class'])
# Out:
# 0.6824999999999999

# %%
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
models_report = pd.DataFrame(columns=cols)
from sklearn import metrics
tmp4 = pd.Series({'Model': 'Logistic Regressin having more than 10 VIF values',
                 'R_Squared Value': model4.prsquared,
                 'ROC score': metrics.roc_auc_score(y_test,predicted_df4['Predicted_Class']),
                 'Precision Score': metrics.precision_score(y_test,predicted_df4['Predicted_Class']),
                 'Recall Score': metrics.recall_score(y_test,predicted_df4['Predicted_Class']),
                 'Accuracy_Score': metrics.accuracy_score(y_test,predicted_df4['Predicted_Class']),
                 'Kappa_Score': metrics.cohen_kappa_score(y_test,predicted_df4['Predicted_Class'])})

model4_report = models_report.append(tmp4, ignore_index=True)
model4_report
# Out:
#                                                Model  R_Squared Value  \
# 0  Logistic Regressin having more than 10 VIF values          0.16994
#
#    ROC score  Precision Score  Recall Score  Accuracy_Score  Kappa_Score
# 0     0.6825         0.765182         0.945            0.77     0.413598

# %%
# comparison of logistic regression models after removing credit amount and duration of credit month and with the variables having more than 10 VIF
cols = ['Model','R_Squared Value','ROC score','Precision Score','Recall Score','Accuracy_Score', 'Kappa_Score']
model_LR = pd.DataFrame(columns=cols)
model_LR=model_LR.append([model1_report,model2_report,model3_report,model4_report],ignore_index=True)
model_LR
# we can able to see the model performance has improved in terms ROC score,Recall Score,Accuracy_score
# Out:
#                                                Model  R_Squared Value  \
# 0                      Logistic Regressin Base Model         0.197014
# 1  Logistic Regressin Base Model after removing C...         0.194992
# 2  Logistic Regressin Base Model after removing  ...         0.188589
# 3  Logistic Regressin having more than 10 VIF values         0.169940
#
#    ROC score  Precision Score  Recall Score  Accuracy_Score  Kappa_Score
# 0     0.6475         0.745968         0.925        0.740000     0.335227
# 1     0.6550         0.751020         0.920        0.743333     0.349296
# 2     0.6550         0.750000         0.930        0.746667     0.352273
# 3     0.6825         0.765182         0.945        0.770000     0.413598

# %% [markdown]
# # 5.6 Removing Insignificant Variable

# %%
X=x_train_vif
Y=y_train
def feature_selection(X,Y,initial_list=[],threshold_in=0.05,threshold_out=0.05,verbose=True):
    """Perform a forward-backward feature selection based on p value from statsmodel.api.OLS
    Arguments:
    X-pandas.dataframe wit candidate features
    Y-list-like with the target
    initial_list- list of featureees to start with column names of X
    threshold_in- include a feature if its p<thrshold_in
    threshold_out-exclude a feature if its p>thrshold_in
    verbose-whether to print the sequence of inclusions and exclusions
    returns:list of selected features
    always set threshold_in<threshold_out to avoid infinite looping
    see https://en.wikipedia.org/wiki/Stepwise_regression for the details
    """
    included=list(initial_list)
    while True:
        changed=False
        # forward step
        excluded=list(set(X.columns)-set(included))
        new_pval=pd.Series(index=excluded) 
        for new_column in excluded:
            model=sm.OLS(Y,sm.add_constant((X[included+[new_column]]))).fit()
            new_pval[new_column]=model.pvalues[new_column]
        best_pval=new_pval.min()
        if best_pval<threshold_in:
            best_feature=new_pval.argmin()
            included.append(best_feature)
            changed=True
            if verbose:
                print('Add {:30} with p-value{:.6}'.format(best_feature,best_pval))
        #backward_step
        model=sm.OLS(Y,sm.add_constant(pd.DataFrame(X[included]))).fit()
        #use all coefs except intercept
        pvalues=model.pvalues.iloc[1:]
        worst_pval=pvalues.max()# null if pvalues is empty
        if worst_pval>threshold_out:
            changed=True
            worst_feature=pvalues.argmax()
            included.remove(worst_feature)
            if verbose:
                print('Drop {:30} with p-value {:.6}'.format(worst_feature,worst_pval))
        if not changed:
            break
    return included
result=feature_selection(X,Y)

print(result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9fdedc56bb25> in <module>
# ----> 1 X=x_train_vif
#       2 Y=y_train
#       3 def feature_selection(X,Y,initial_list=[],threshold_in=0.05,threshold_out=0.05,verbose=True):
#       4     """Perform a forward-backward feature selection based on p value from statsmodel.api.OLS
#       5     Arguments:
#
# NameError: name 'x_train_vif' is not defined
