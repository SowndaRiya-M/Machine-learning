# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\sowndariya\anaconda3\lib\site-packages (1.14.0)
# Requirement already satisfied: wheel>=0.26 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied: absl-py>=0.7.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied: google-pasta>=0.1.6 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: protobuf>=3.6.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: grpcio>=1.8.6 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.33.2)
# Requirement already satisfied: gast>=0.2.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Requirement already satisfied: astor>=0.6.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.8.1)
# Requirement already satisfied: keras-applications>=1.0.6 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.0.8)
# Requirement already satisfied: six>=1.10.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied: setuptools in c:\users\sowndariya\anaconda3\lib\site-packages (from protobuf>=3.6.1->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow) (3.3.3)
# Requirement already satisfied: h5py in c:\users\sowndariya\anaconda3\lib\site-packages (from keras-applications>=1.0.6->tensorflow) (2.10.0)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\users\sowndariya\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow) (1.5.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade tensorflow
# Out:
# Requirement already up-to-date: tensorflow in c:\users\sowndariya\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied, skipping upgrade: astunparse==1.6.3 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied, skipping upgrade: google-pasta>=0.1.8 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied, skipping upgrade: numpy<1.19.0,>=1.16.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.18.1)
# Requirement already satisfied, skipping upgrade: termcolor>=1.1.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied, skipping upgrade: absl-py>=0.7.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.11.0)
# Requirement already satisfied, skipping upgrade: grpcio>=1.8.6 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.33.2)
# Requirement already satisfied, skipping upgrade: keras-preprocessing<1.2,>=1.1.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied, skipping upgrade: wheel>=0.26 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.34.2)
# Requirement already satisfied, skipping upgrade: h5py<2.11.0,>=2.10.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied, skipping upgrade: tensorboard<3,>=2.3.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied, skipping upgrade: gast==0.3.3 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied, skipping upgrade: wrapt>=1.11.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.11.2)
# Requirement already satisfied, skipping upgrade: opt-einsum>=2.3.2 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied, skipping upgrade: protobuf>=3.9.2 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied, skipping upgrade: six>=1.12.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (1.14.0)
# Requirement already satisfied, skipping upgrade: tensorflow-estimator<2.4.0,>=2.3.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorflow) (2.3.0)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.21.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (2.22.0)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (0.4.2)
# Requirement already satisfied, skipping upgrade: google-auth<2,>=1.6.3 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.23.0)
# Requirement already satisfied, skipping upgrade: markdown>=2.6.8 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (3.3.3)
# Requirement already satisfied, skipping upgrade: setuptools>=41.0.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied, skipping upgrade: werkzeug>=0.11.15 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.0.0)
# Requirement already satisfied, skipping upgrade: tensorboard-plugin-wit>=1.6.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from tensorboard<3,>=2.3.0->tensorflow) (1.7.0)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\sowndariya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2019.11.28)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in c:\users\sowndariya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (3.0.4)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (1.25.8)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<3,>=2.3.0->tensorflow) (2.8)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in c:\users\sowndariya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.2.8)
# Requirement already satisfied, skipping upgrade: cachetools<5.0,>=2.0.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.1.1)
# Requirement already satisfied, skipping upgrade: rsa<5,>=3.1.4; python_version >= "3.5" in c:\users\sowndariya\anaconda3\lib\site-packages (from google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (4.6)
# Requirement already satisfied, skipping upgrade: importlib-metadata; python_version < "3.8" in c:\users\sowndariya\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (1.5.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in c:\users\sowndariya\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<3,>=2.3.0->tensorflow) (3.1.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in c:\users\sowndariya\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<3,>=2.3.0->tensorflow) (0.4.8)
# Requirement already satisfied, skipping upgrade: zipp>=0.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<3,>=2.3.0->tensorflow) (2.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
from PIL import Image
im = Image.open("dhoni images.jpg")
im.rotate(45).show()

# %%
from PIL import Image
im = Image.open("dhoni images.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=236x314 at 0x21B45835548>

# %%
from PIL import Image
im = Image.open("pexels-photo-1878293.jpeg")
im.rotate(45).show()

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.4.0.46-cp37-cp37m-win_amd64.whl (33.5 MB)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\sowndariya\anaconda3\lib\site-packages (from opencv-python) (1.18.1)
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.4.0.46
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pydot
# Out:
# Collecting pydot
#   Downloading pydot-1.4.1-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\sowndariya\anaconda3\lib\site-packages (from pydot) (2.4.6)
# Installing collected packages: pydot
# Successfully installed pydot-1.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\sowndariya\appdata\roaming\python\python37\site-packages (0.14.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import graphviz

# %%
from graphviz import Digraph

g = Digraph('G', filename='hello.gv')

g.edge('Hello', 'World')

g.view()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python37\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     163     try:
# --> 164         proc = subprocess.Popen(cmd, startupinfo=get_startupinfo(), **kwargs)
#     165     except OSError as e:
#
# ~\anaconda3\lib\subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, encoding, errors, text)
#     799                                 errread, errwrite,
# --> 800                                 restore_signals, start_new_session)
#     801         except:
#
# ~\anaconda3\lib\subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_start_new_session)
#    1206                                          os.fspath(cwd) if cwd is not None else None,
# -> 1207                                          startupinfo)
#    1208             finally:
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# During handling of the above exception, another exception occurred:
#
# ExecutableNotFound                        Traceback (most recent call last)
# <ipython-input-4-08752f350584> in <module>
#       5 g.edge('Hello', 'World')
#       6
# ----> 7 g.view()
#
# ~\AppData\Roaming\Python\Python37\site-packages\graphviz\files.py in view(self, filename, directory, cleanup, quiet, quiet_view)
#     244         return self.render(filename=filename, directory=directory,
#     245                            view=True, cleanup=cleanup,
# --> 246                            quiet=quiet, quiet_view=quiet_view)
#     247
#     248     def _view(self, filepath, format, quiet):
#
# ~\AppData\Roaming\Python\Python37\site-packages\graphviz\files.py in render(self, filename, directory, view, cleanup, format, renderer, formatter, quiet, quiet_view)
#     207         rendered = backend.render(self._engine, format, filepath,
#     208                                   renderer=renderer, formatter=formatter,
# --> 209                                   quiet=quiet)
#     210
#     211         if cleanup:
#
# ~\AppData\Roaming\Python\Python37\site-packages\graphviz\backend.py in render(***failed resolving arguments***)
#     219         cwd = None
#     220
# --> 221     run(cmd, capture_output=True, cwd=cwd, check=True, quiet=quiet)
#     222     return rendered
#     223
#
# ~\AppData\Roaming\Python\Python37\site-packages\graphviz\backend.py in run(cmd, input, capture_output, check, encoding, quiet, **kwargs)
#     165     except OSError as e:
#     166         if e.errno == errno.ENOENT:
# --> 167             raise ExecutableNotFound(cmd)
#     168         else:
#     169             raise
#
# ExecutableNotFound: failed to execute ['dot', '-Tpdf', '-O', 'hello.gv'], make sure the Graphviz executables are on your systems' PATH

# %%
conda install graphviz
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install graphviz
# Out:
# Requirement already satisfied: graphviz in c:\users\sowndariya\appdata\roaming\python\python37\site-packages (0.14.2)
# Note: you may need to restart the kernel to use updated packages.
